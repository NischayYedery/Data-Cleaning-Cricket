# %%
import pandas as pd

# %%
df = pd.read_csv("CricketTestMatchData.csv")
df
# Out:
#                Player       Span  Mat  Inns  NO  Runs    HS    Ave     BF  \
# 0    DG Bradman (AUS)  1928-1948   52    80  10  6996   334  99.94  9800+
# 1      AC Voges (AUS)  2015-2016   20    31   7  1485  269*  61.87   2667
# 2     RG Pollock (SA)  1963-1970   23    41   4  2256   274  60.97  1707+
# 3     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# 4     GA Headley (WI)  1930-1954   22    40   4  2190  270*  60.83   416+
# ..                ...        ...  ...   ...  ..   ...   ...    ...    ...
# 60   KD Walters (AUS)  1965-1981   74   125  14  5357   250  48.26  8662+
# 61  GC Smith (ICC/SA)  2002-2014  117   205  13  9265   277  48.25  15525
# 62  WH Ponsford (AUS)  1924-1934   29    48   4  2122   266  48.22  3118+
# 63    SJ McCabe (AUS)  1930-1938   39    62   5  2748   232  48.21  3217+
# 64   DR Jardine (ENG)  1928-1934   22    33   6  1296   127  48.00  2110+
#
#        SR  100  50   0    4s  6s
# 0   58.60   29  13   7  626+   6
# ...

# %%
df=df.rename(columns={'Mat':'Matches_Played','No':'Not_Outs','HS':'Highest_Inns_score','Ave':'Average','BF':'Ball_Faced','SR':'Strike_Rate'})

# %%
df
# Out:
#                Player       Span  Matches_Played  Inns  NO  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52    80  10  6996
# 1      AC Voges (AUS)  2015-2016              20    31   7  1485
# 2     RG Pollock (SA)  1963-1970              23    41   4  2256
# 3     GA Headley (WI)  1930-1954              22    40   4  2190
# 4     GA Headley (WI)  1930-1954              22    40   4  2190
# ..                ...        ...             ...   ...  ..   ...
# 60   KD Walters (AUS)  1965-1981              74   125  14  5357
# 61  GC Smith (ICC/SA)  2002-2014             117   205  13  9265
# 62  WH Ponsford (AUS)  1924-1934              29    48   4  2122
# 63    SJ McCabe (AUS)  1930-1938              39    62   5  2748
# 64   DR Jardine (ENG)  1928-1934              22    33   6  1296
#
#    Highest_Inns_score  Average Ball_Faced  Strike_Rate  100  50   0    4s  6s
# 0                 334    99.94      9800+        58.60   29  13   7  626+   6
# ...

# %%
df.isnull().any()
# Out:
# Player                False
# Span                  False
# Matches_Played        False
# Inns                  False
# NO                    False
# Runs                  False
# Highest_Inns_score    False
# Average               False
# Ball_Faced             True
# Strike_Rate            True
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# dtype: bool

# %%
df[df['Ball_Faced'].isna()==1]
# Out:
#              Player       Span  Matches_Played  Inns  NO  Runs  \
# 8    ED Weekes (WI)  1948-1958              48    81   5  4455
# 16  CL Walcott (WI)  1948-1960              44    74   7  3798
#
#    Highest_Inns_score  Average Ball_Faced  Strike_Rate  100  50  0    4s  6s
# 8                 207    58.61        NaN          NaN   15  19  6  258+   2
# 16                220    56.68        NaN          NaN   15  14  1  107+  11

# %%
df['Ball_Faced'] = df['Ball_Faced'].fillna(0)

# %%
df['Strike_Rate']=df['Strike_Rate'].fillna(0)

# %%
df[df['Player']=='CL Walcott (WI)']
# Out:
#              Player       Span  Matches_Played  Inns  NO  Runs  \
# 16  CL Walcott (WI)  1948-1960              44    74   7  3798
#
#    Highest_Inns_score  Average Ball_Faced  Strike_Rate  100  50  0    4s  6s
# 16                220    56.68          0          0.0   15  14  1  107+  11

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4      True
#       ...
# 60    False
# 61    False
# 62    False
# 63    False
# 64    False
# Length: 65, dtype: bool

# %%
df=df.drop_duplicates()

# %%
df
# Out:
#                Player       Span  Matches_Played  Inns  NO  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52    80  10  6996
# 1      AC Voges (AUS)  2015-2016              20    31   7  1485
# 2     RG Pollock (SA)  1963-1970              23    41   4  2256
# 3     GA Headley (WI)  1930-1954              22    40   4  2190
# 5   H Sutcliffe (ENG)  1924-1935              54    84   9  4555
# ..                ...        ...             ...   ...  ..   ...
# 60   KD Walters (AUS)  1965-1981              74   125  14  5357
# 61  GC Smith (ICC/SA)  2002-2014             117   205  13  9265
# 62  WH Ponsford (AUS)  1924-1934              29    48   4  2122
# 63    SJ McCabe (AUS)  1930-1938              39    62   5  2748
# 64   DR Jardine (ENG)  1928-1934              22    33   6  1296
#
#    Highest_Inns_score  Average Ball_Faced  Strike_Rate  100  50   0    4s  6s
# 0                 334    99.94      9800+        58.60   29  13   7  626+   6
# ...

# %% [markdown]
# #Split it into Start and end date

# %%
df['Span'].str.split('-')  ## we can use pat also example is .split(pat = '-')
# Out:
# 0     [1928, 1948]
# 1     [2015, 2016]
# 2     [1963, 1970]
# 3     [1930, 1954]
# 5     [1924, 1935]
#           ...
# 60    [1965, 1981]
# 61    [2002, 2014]
# 62    [1924, 1934]
# 63    [1930, 1938]
# 64    [1928, 1934]
# Name: Span, Length: 61, dtype: object

# %%
df['Start_Year']=df['Span'].str.split('-').str[0]
# Out:
# C:\Users\Nischay Yedery\AppData\Local\Temp\ipykernel_40404\500842447.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Start_Year']=df['Span'].str.split('-').str[0]

# %%
df['End_Year']=df['Span'].str.split('-').str[1]
# Out:
# C:\Users\Nischay Yedery\AppData\Local\Temp\ipykernel_40404\1317316137.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['End_Year']=df['Span'].str.split('-').str[1]

# %%
df
# Out:
#                Player       Span  Matches_Played  Inns  NO  Runs  \
# 0    DG Bradman (AUS)  1928-1948              52    80  10  6996
# 1      AC Voges (AUS)  2015-2016              20    31   7  1485
# 2     RG Pollock (SA)  1963-1970              23    41   4  2256
# 3     GA Headley (WI)  1930-1954              22    40   4  2190
# 5   H Sutcliffe (ENG)  1924-1935              54    84   9  4555
# ..                ...        ...             ...   ...  ..   ...
# 60   KD Walters (AUS)  1965-1981              74   125  14  5357
# 61  GC Smith (ICC/SA)  2002-2014             117   205  13  9265
# 62  WH Ponsford (AUS)  1924-1934              29    48   4  2122
# 63    SJ McCabe (AUS)  1930-1938              39    62   5  2748
# 64   DR Jardine (ENG)  1928-1934              22    33   6  1296
#
#    Highest_Inns_score  Average Ball_Faced  Strike_Rate  100  50   0    4s  6s  \
# 0                 334    99.94      9800+        58.60   29  13   7  626+   6
# ...

# %%
df = df.drop(columns="Span")
df
# Out:
#                Player  Matches_Played  Inns  NO  Runs Highest_Inns_score  \
# 0    DG Bradman (AUS)              52    80  10  6996                334
# 1      AC Voges (AUS)              20    31   7  1485               269*
# 2     RG Pollock (SA)              23    41   4  2256                274
# 3     GA Headley (WI)              22    40   4  2190               270*
# 5   H Sutcliffe (ENG)              54    84   9  4555                194
# ..                ...             ...   ...  ..   ...                ...
# 60   KD Walters (AUS)              74   125  14  5357                250
# 61  GC Smith (ICC/SA)             117   205  13  9265                277
# 62  WH Ponsford (AUS)              29    48   4  2122                266
# 63    SJ McCabe (AUS)              39    62   5  2748                232
# 64   DR Jardine (ENG)              22    33   6  1296                127
#
#     Average Ball_Faced  Strike_Rate  100  50   0    4s  6s Start_Year End_Year
# ...

# %%
df
# Out:
#                Player  Matches_Played  Inns  NO  Runs Highest_Inns_score  \
# 0    DG Bradman (AUS)              52    80  10  6996                334
# 1      AC Voges (AUS)              20    31   7  1485               269*
# 2     RG Pollock (SA)              23    41   4  2256                274
# 3     GA Headley (WI)              22    40   4  2190               270*
# 5   H Sutcliffe (ENG)              54    84   9  4555                194
# ..                ...             ...   ...  ..   ...                ...
# 60   KD Walters (AUS)              74   125  14  5357                250
# 61  GC Smith (ICC/SA)             117   205  13  9265                277
# 62  WH Ponsford (AUS)              29    48   4  2122                266
# 63    SJ McCabe (AUS)              39    62   5  2748                232
# 64   DR Jardine (ENG)              22    33   6  1296                127
#
#     Average Ball_Faced  Strike_Rate  100  50   0    4s  6s Start_Year End_Year
# ...

# %%
df['Player'].str.split('(')
# Out:
# 0      [DG Bradman , AUS)]
# 1        [AC Voges , AUS)]
# 2       [RG Pollock , SA)]
# 3       [GA Headley , WI)]
# 5     [H Sutcliffe , ENG)]
#               ...
# 60     [KD Walters , AUS)]
# 61    [GC Smith , ICC/SA)]
# 62    [WH Ponsford , AUS)]
# 63      [SJ McCabe , AUS)]
# 64     [DR Jardine , ENG)]
# Name: Player, Length: 61, dtype: object

# %%
df['Country']= df['Player'].str.split('(').str[1]

# %%
df['Country'].str.split(')')
# Out:
# 0        [AUS, ]
# 1        [AUS, ]
# 2         [SA, ]
# 3         [WI, ]
# 5        [ENG, ]
#          ...
# 60       [AUS, ]
# 61    [ICC/SA, ]
# 62       [AUS, ]
# 63       [AUS, ]
# 64       [ENG, ]
# Name: Country, Length: 61, dtype: object

# %%
df['Country']= df['Player'].str.split('(').str[1]

# %%
df['Country'].str.split(')')
# Out:
# 0        [AUS, ]
# 1        [AUS, ]
# 2         [SA, ]
# 3         [WI, ]
# 5        [ENG, ]
#          ...
# 60       [AUS, ]
# 61    [ICC/SA, ]
# 62       [AUS, ]
# 63       [AUS, ]
# 64       [ENG, ]
# Name: Country, Length: 61, dtype: object

# %%
df['Country']=df['Country'].str.split(')').str[0]

# %%
df['Country']
# Out:
# 0        AUS
# 1        AUS
# 2         SA
# 3         WI
# 5        ENG
#        ...
# 60       AUS
# 61    ICC/SA
# 62       AUS
# 63       AUS
# 64       ENG
# Name: Country, Length: 61, dtype: object

# %%
df['Player']=df['Player'].str.split('(').str[0]

# %%
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                334    99.94
# 1      AC Voges               20    31   7  1485               269*    61.87
# 2    RG Pollock               23    41   4  2256                274    60.97
# 3    GA Headley               22    40   4  2190               270*    60.83
# 5   H Sutcliffe               54    84   9  4555                194    60.73
# ..           ...             ...   ...  ..   ...                ...      ...
# 60   KD Walters               74   125  14  5357                250    48.26
# 61     GC Smith              117   205  13  9265                277    48.25
# 62  WH Ponsford               29    48   4  2122                266    48.22
# 63    SJ McCabe               39    62   5  2748                232    48.21
# 64   DR Jardine               22    33   6  1296                127    48.00
#
# ...

# %%
df.dtypes
# Out:
# Player                 object
# Matches_Played          int64
# Inns                    int64
# NO                      int64
# Runs                    int64
# Highest_Inns_score     object
# Average               float64
# Ball_Faced             object
# Strike_Rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Start_Year             object
# End_Year               object
# Country                object
# dtype: object

# %%
df['Highest_Inns_score'].str.split('*').str[0]
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_score, Length: 61, dtype: object

# %%
df['Highest_Inns_score'] = df['Highest_Inns_score'].str.split('*').str[0]

# %%
df['Highest_Inns_score']
# Out:
# 0     334
# 1     269
# 2     274
# 3     270
# 5     194
#      ...
# 60    250
# 61    277
# 62    266
# 63    232
# 64    127
# Name: Highest_Inns_score, Length: 61, dtype: object

# %%
df['Highest_Inns_score']= df['Highest_Inns_score'].astype('int')

# %%
df.dtypes
# Out:
# Player                 object
# Matches_Played          int64
# Inns                    int64
# NO                      int64
# Runs                    int64
# Highest_Inns_score      int32
# Average               float64
# Ball_Faced             object
# Strike_Rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                     object
# 6s                     object
# Start_Year             object
# End_Year               object
# Country                object
# dtype: object

# %%
df['4s'].str.split('+')
# Out:
# 0     [626, ]
# 1       [186]
# 2     [246, ]
# 3     [104, ]
# 5     [202, ]
#        ...
# 60    [525, ]
# 61     [1165]
# 62    [119, ]
# 63    [241, ]
# 64     [53, ]
# Name: 4s, Length: 61, dtype: object

# %%
df['4s']=df['4s'].str.split('+').str[0]

# %%
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
df['6s'].str.split('+')
# Out:
# 0       [6]
# 1       [5]
# 2      [11]
# 3       [1]
# 5       [6]
#       ...
# 60     [23]
# 61     [24]
# 62      [0]
# 63    [5, ]
# 64      [0]
# Name: 6s, Length: 61, dtype: object

# %%
df['6s']=df['6s'].str.split('+').str[0]

# %%
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
df['4s']=df['4s'].astype('int')
df['6s']=df['6s'].astype('int')

# %%
df.dtypes
# Out:
# Player                 object
# Matches_Played          int64
# Inns                    int64
# NO                      int64
# Runs                    int64
# Highest_Inns_score      int32
# Average               float64
# Ball_Faced             object
# Strike_Rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int32
# 6s                      int32
# Start_Year             object
# End_Year               object
# Country                object
# dtype: object

# %%
df['Start_Year']=df['Start_Year'].astype('int')

# %%
df['End_Year']=df['End_Year'].astype('int')

# %%
df.dtypes
# Out:
# Player                 object
# Matches_Played          int64
# Inns                    int64
# NO                      int64
# Runs                    int64
# Highest_Inns_score      int32
# Average               float64
# Ball_Faced             object
# Strike_Rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int32
# 6s                      int32
# Start_Year              int32
# End_Year                int32
# Country                object
# dtype: object

# %%
df['Ball_Faced'].str.split('+')
# Out:
# 0     [9800, ]
# 1       [2667]
# 2     [1707, ]
# 3      [416, ]
# 5     [6558, ]
#         ...
# 60    [8662, ]
# 61     [15525]
# 62    [3118, ]
# 63    [3217, ]
# 64    [2110, ]
# Name: Ball_Faced, Length: 61, dtype: object

# %%
df['Ball_Faced']=df['Ball_Faced'].str.split('+').str[0]

# %%
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
df[df['Ball_Faced'].isna()==1]
# Out:
#          Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 8    ED Weekes               48    81   5  4455                 207    58.61
# 16  CL Walcott               44    74   7  3798                 220    56.68
#
#    Ball_Faced  Strike_Rate  100  50  0   4s  6s  Start_Year  End_Year Country
# 8         NaN          0.0   15  19  6  258   2        1948      1958      WI
# 16        NaN          0.0   15  14  1  107  11        1948      1960      WI

# %%
df=df.drop_duplicates()
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
df['Ball_Faced']=df['Ball_Faced'].str.replace('NaN','0')

# %%
df[df['Ball_Faced'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Player, Matches_Played, Inns, NO, Runs, Highest_Inns_score, Average, Ball_Faced, Strike_Rate, 100, 50, 0, 4s, 6s, Start_Year, End_Year, Country]
# Index: []

# %%
df['Ball_Faced']=df['Ball_Faced'].fillna(0)

# %%
df['Ball_Faced']=df['Ball_Faced'].replace('-','0').str[0]

# %%
df['Ball_Faced']=df['Ball_Faced'].astype('int')

# %%
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
df.dtypes
# Out:
# Player                 object
# Matches_Played          int64
# Inns                    int64
# NO                      int64
# Runs                    int64
# Highest_Inns_score      int32
# Average               float64
# Ball_Faced              int32
# Strike_Rate           float64
# 100                     int64
# 50                      int64
# 0                       int64
# 4s                      int32
# 6s                      int32
# Start_Year              int32
# End_Year                int32
# Country                object
# dtype: object

# %%
df.isnull().any()
# Out:
# Player                False
# Matches_Played        False
# Inns                  False
# NO                    False
# Runs                  False
# Highest_Inns_score    False
# Average               False
# Ball_Faced            False
# Strike_Rate           False
# 100                   False
# 50                    False
# 0                     False
# 4s                    False
# 6s                    False
# Start_Year            False
# End_Year              False
# Country               False
# dtype: bool

# %%
#Question build out Career Length

# %%
df['Careerlenght'] = df['End_Year']-df['Start_Year']
df
# Out:
#           Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  Average  \
# 0    DG Bradman               52    80  10  6996                 334    99.94
# 1      AC Voges               20    31   7  1485                 269    61.87
# 2    RG Pollock               23    41   4  2256                 274    60.97
# 3    GA Headley               22    40   4  2190                 270    60.83
# 5   H Sutcliffe               54    84   9  4555                 194    60.73
# ..           ...             ...   ...  ..   ...                 ...      ...
# 60   KD Walters               74   125  14  5357                 250    48.26
# 61     GC Smith              117   205  13  9265                 277    48.25
# 62  WH Ponsford               29    48   4  2122                 266    48.22
# 63    SJ McCabe               39    62   5  2748                 232    48.21
# 64   DR Jardine               22    33   6  1296                 127    48.00
#
# ...

# %%
#Q1 Avg career Length

# %%
df['Careerlenght'].mean()
# Out:
# 13.131147540983607

# %%
#Q2 Avg strike rate for cricketers who played over 10 years

# %%
df[df['Careerlenght'] >10]['Strike_Rate'].mean()
# Out:
# 47.80162790697674

# %%
#Q3 no of cricketers who played before 1960

# %%
df[df['End_Year']<1960]
# Out:
#              Player  Matches_Played  Inns  NO  Runs  Highest_Inns_score  \
# 0       DG Bradman               52    80  10  6996                 334
# 3       GA Headley               22    40   4  2190                 270
# 5      H Sutcliffe               54    84   9  4555                 194
# 6        E Paynter               20    31   5  1540                 243
# 8        ED Weekes               48    81   5  4455                 207
# 10      WR Hammond               85   140  16  7249                 336
# 14        JB Hobbs               61   102   7  5410                 211
# 17        L Hutton               79   138  15  6971                 364
# 20    GE Tyldesley               14    20   2   990                 122
# 25       AD Nourse               34    62   7  2960                 231
# 35         J Ryder               20    32   5  1394                 201
# 46     DCS Compton               78   131  15  5807                 278
# ...

# %%
#Q4 max highest Inns score by country

# %%
df.groupby('Country')['Highest_Inns_score'].max().head(4)
# Out:
# Country
# AUS        380
# ENG        364
# ICC/IND    319
# ICC/PAK    329
# Name: Highest_Inns_score, dtype: int32

# %%
#Q5 Hundreds,fifties,ducks(0) Avg by country

# %%
df.groupby('Country')[['100','50','0']].mean()
# Out:
#                100         50          0
# Country
# AUS      21.400000  28.933333   8.933333
# ENG      13.076923  21.384615   4.461538
# ICC/IND  29.500000  47.500000  12.000000
# ICC/PAK  25.000000  46.000000  15.000000
# ICC/SA   36.000000  48.000000  13.500000
# ICC/WI   34.000000  48.000000  17.000000
# IND      23.250000  31.500000   8.000000
# NZ       33.000000  37.000000  11.000000
# PAK      17.800000  24.000000   8.000000
# SA        9.800000  20.200000   3.400000
# SL       28.666667  44.000000  12.333333
# WI       16.625000  25.625000   7.250000
# ZIM      12.000000  27.000000   5.000000
